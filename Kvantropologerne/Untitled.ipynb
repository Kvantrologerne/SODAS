# %%
import pandas as pd
import re
from wordcloud import WordCloud

# %%
uffe = pd.read_csv('Elbaek_got.csv')

# %%
print(uffe['id'].tail())
# Out:
# 17403    363721912125370368
# 17404    363721299832487936
# 17405    363283605910339585
# 17406    362959623017332737
# 17407    362940451168333825
# Name: id, dtype: int64

# %%
alltext = ""
for tweet in uffe.text:
    try:
        tweet = tweet.split("https")[0]
    except AttributeError:
        continue
    alltext = alltext + " " + tweet

# %%
re.split(r'\W', alltext)
# Out:
# ['',
#  'Nuanceret',
#  'og',
#  'grundig',
#  '',
#  'og',
#  'forholdsvis',
#  'kort',
#  '',
#  'gennemgang',
#  'af',
#  'konflikten',
#  'i',
#  'Hong',
#  'Kong',
#  '',
#  'Og',
#  'ikke',
#  'mindst',
#  'et',
#  'godt',
#  'indblik',
#  'i',
#  'hvem',
#  'der',
#  'har',
#  'hvilke',
#  'roller',
#  'interesser',
#  'og',
#  'hvorfor',
#  '',
#  'Så',
#  'kan',
#  'klart',
#  'anbefales',
#  '',
#  '',
#  'dkpol',
#  '',
#  'Der',
#  'bør',
#  'signaleres',
#  'tydeligt',
#  'her',
#  'og',
#  'laves',
#  'et',
#  'generelt',
#  'forbud',
#  'mod',
#  'våben',
#  'og',
#  'dual',
#  'use',
#  'produkter',
#  'til',
#  'Tyrkiet',
#  '',
#  'og',
#  'ikke',
#  'blot',
#  'hvor',
#  'de',
#  'vil',
#  'kunne',
#  'eller',
#  'skulle',
#  'bruges',
#  'i',
#  'Syrien',
#  '',
#  '',
#  'siger',
#  '',
#  'rasmusnordqvist',
#  '',
#  'Stop',
#  'ny',
#  'oliejagt',
#  'i',
#  'Nordsøen',
#  '',
#  'Det',
#  'vil',
#  'være',
#  'dårligt',
#  'for',
#  'klimaet',
#  '',
#  '',
#  'og',
#  'økonomien',
#  'hænger',
#  'også',
#  'dårligere',
#  'og',
#  'dårligere',
#  'sammen',
#  '',
#  'Kunne',
#  'ikke',
#  'have',
#  'sagt',
#  'det',
#  'bedre',
#  'selv',
#  '',
#  'Frej',
#  '',
#  'Kæmpe',
#  'godt',
#  'gået',
#  '',
#  'Så',
#  'flot',
#  '',
#  'Og',
#  'imponerende',
#  '',
#  'Det',
#  'er',
#  'ikke',
#  'min',
#  'oplevelse',
#  '',
#  'Jeg',
#  'ser',
#  'unge',
#  '',
#  'voksne',
#  '',
#  'gamle',
#  '',
#  'som',
#  'tager',
#  'klimakrisen',
#  'så',
#  'alvorligt',
#  '',
#  'at',
#  'de',
#  'bliver',
#  'nødt',
#  'til',
#  'at',
#  'handle',
#  '',
#  'Hvis',
#  'du',
#  'læser',
#  'artiklen',
#  'er',
#  'det',
#  'også',
#  'dens',
#  'budskab',
#  'At',
#  'der',
#  'så',
#  'samtidig',
#  'er',
#  'brug',
#  'for',
#  'alle',
#  'mulige',
#  'andre',
#  'måder',
#  'at',
#  'skubbe',
#  'verden',
#  'i',
#  'bedre',
#  'verden',
#  'er',
#  'også',
#  'nødvendigt',
#  '',
#  'Det',
#  'synes',
#  'jeg',
#  'ikke',
#  'om',
#  '',
#  'Og',
#  'der',
#  'er',
#  'da',
#  'også',
#  'nogle',
#  'af',
#  'deres',
#  'aktioner',
#  '',
#  'som',
#  'jeg',
#  'faktisk',
#  'synes',
#  'har',
#  'været',
#  'helt',
#  'forfejlet',
#  '',
#  'Men',
#  'til',
#  'gengæld',
#  'er',
#  'der',
#  'også',
#  'masser',
#  'af',
#  'det',
#  'de',
#  'gør',
#  '',
#  'som',
#  'jeg',
#  'som',
#  'sagt',
#  'kun',
#  'har',
#  'respekt',
#  'for',
#  '',
#  'Det',
#  'hele',
#  'skal',
#  'ses',
#  'i',
#  'det',
#  'perspektiv',
#  '',
#  'at',
#  'politikerne',
#  'ikke',
#  'rykker',
#  'hurtigt',
#  'nok',
#  '',
#  'Den',
#  'er',
#  'jo',
#  'netop',
#  'ikke',
#  'voldelig',
#  'Og',
#  'som',
#  'sagt',
#  'har',
#  'jeg',
#  'respekt',
#  'for',
#  'alle',
#  'de',
#  'mennesker',
#  'som',
#  'nu',
#  'går',
#  'på',
#  'gaden',
#  '',
#  'fordi',
#  'de',
#  'synes',
#  '',
#  'at',
#  'det',
#  'går',
#  'alt',
#  '',
#  'alt',
#  'for',
#  'langsomt',
#  'med',
#  'den',
#  'grønne',
#  'omstilling',
#  '',
#  'Men',
#  'læs',
#  'endelig',
#  'artiklen',
#  '',
#  'For',
#  'det',
#  'de',
#  'gør',
#  'her',
#  'svarede',
#  'til',
#  'det',
#  'borgerrettighedsbevægelsen',
#  'gjorde',
#  'i',
#  '60erne',
#  'Der',
#  'er',
#  'politisk',
#  'dårlige',
#  'nyheder',
#  'nok',
#  'lige',
#  'nu',
#  '',
#  'Så',
#  'når',
#  'der',
#  'endelig',
#  'er',
#  'en',
#  'rigtig',
#  'god',
#  'en',
#  'af',
#  'slagsen',
#  '',
#  'er',
#  'det',
#  'da',
#  'bare',
#  'med',
#  'at',
#  'få',
#  'råbt',
#  'den',
#  'ud',
#  'over',
#  'husenes',
#  'tage',
#  '',
#  'Så',
#  'her',
#  'kommer',
#  'den',
#  '',
#  'progressiv',
#  'borgmester',
#  'valgt',
#  'i',
#  'Ungarns',
#  'hovedstad',
#  '',
#  'Yes',
#  '',
#  'Det',
#  'så',
#  'jeg',
#  'godt',
#  '',
#  'Den',
#  'grønne',
#  'omstilling',
#  'går',
#  'alt',
#  '',
#  'alt',
#  'for',
#  'langsom',
#  '',
#  'hvis',
#  'vi',
#  'skal',
#  'nå',
#  'de',
#  'mål',
#  '',
#  'som',
#  'er',
#  'forudsætningen',
#  'for',
#  '',
#  'at',
#  'vi',
#  'kan',
#  'overdrage',
#  'bare',
#  'en',
#  'nogenlunde',
#  'stabil',
#  'verden',
#  'til',
#  'vores',
#  'børn',
#  'og',
#  'børnebørn',
#  '',
#  'Hvad',
#  'der',
#  'er',
#  'min',
#  'ambition',
#  '',
#  'Hvad',
#  'er',
#  'din',
#  '',
#  'I',
#  'know',
#  '',
#  'Hvis',
#  'du',
#  'læser',
#  'denne',
#  'artikel',
#  'i',
#  '',
#  'informeren',
#  '',
#  '',
#  'skrevet',
#  'af',
#  '',
#  'jrgensteenniels',
#  '',
#  '',
#  'får',
#  'du',
#  'et',
#  'super',
#  'godt',
#  'indblik',
#  'i',
#  '',
#  'hvorfor',
#  'flere',
#  'og',
#  'flere',
#  'bakker',
#  'op',
#  'om',
#  '',
#  'ExtinctionR',
#  '',
#  'Her',
#  'hjemme',
#  'som',
#  'i',
#  'Europa',
#  'og',
#  'USA',
#  '',
#  'Og',
#  'fra',
#  'min',
#  'side',
#  '',
#  'skal',
#  'der',
#  'blot',
#  'lyde',
#  '',
#  'Respekt',
#  '',
#  '',
#  'dkpol',
#  'How',
#  'do',
#  'Carrie',
#  'Lam',
#  'manipulates',
#  'her',
#  'self',
#  'to',
#  'believe',
#  'in',
#  'what',
#  'she',
#  'is',
#  'saying',
#  '',
#  'About',
#  'what',
#  'is',
#  'happening',
#  'in',
#  'Hong',
#  'Kong',
#  '',
#  'About',
#  'democracy',
#  '',
#  'About',
#  'human',
#  'rights',
#  '',
#  'About',
#  'freedom',
#  'to',
#  'speak',
#  '',
#  'And',
#  'the',
#  'right',
#  'to',
#  'assembly',
#  '',
#  'Who',
#  'are',
#  'really',
#  'inside',
#  'Carrie',
#  'Lam',
#  '',
#  '',
#  'StandWithHongKong',
#  'Og',
#  'fordi',
#  'der',
#  'stadig',
#  '',
#  '',
#  'desværre',
#  '',
#  '',
#  'er',
#  'en',
#  'ubalance',
#  'mellem',
#  'kvinder',
#  'og',
#  'mænds',
#  'arbejdsindsats',
#  'i',
#  'hjemmet',
#  'er',
#  'det',
#  'dobbelt',
#  'uretfærdigt',
#  'at',
#  'der',
#  'også',
#  'er',
#  '10',
#  '15',
#  'procents',
#  'løn',
#  'ulighed',
#  'mellem',
#  'kvinder',
#  'og',
#  'mænd',
#  'på',
#  'det',
#  '',
#  'traditionelle',
#  'arbejdsmarked',
#  '',
#  '',
#  'Min',
#  'pointe',
#  'er',
#  '',
#  'at',
#  'fritid',
#  'ikke',
#  'bare',
#  'er',
#  'fritid',
#  '',
#  'Det',
#  'arbejde',
#  'der',
#  'foregår',
#  'i',
#  'hjemmet',
#  'burde',
#  'deles',
#  'lige',
#  'mellem',
#  'mænd',
#  'og',
#  'kvinder',
#  '',
#  'Hvis',
#  'ikke',
#  'bliver',
#  'begrebet',
#  'fritid',
#  'jo',
#  'helt',
#  'indholdsløst',
#  '',
#  'Jamen',
#  'køn',
#  'betyder',
#  'noget',
#  '',
#  'Endnu',
#  '',
#  'Desværre',
#  '',
#  'Tage',
#  'bare',
#  'os',
#  'mænd',
#  '',
#  'vi',
#  'er',
#  'eksempelvis',
#  'overrepræsenteret',
#  'når',
#  'det',
#  'gælder',
#  'dårligt',
#  'helbred',
#  '',
#  'vi',
#  'dør',
#  'før',
#  'kvinderne',
#  '',
#  '',
#  'klarer',
#  'skilsmisser',
#  'dårligere',
#  'end',
#  'kvinderne',
#  '',
#  'er',
#  'mere',
#  'ensomme',
#  '',
#  'overrepræsenteret',
#  'i',
#  'kriminalitetsstatistikken',
#  'etc',
#  '',
#  'Jeg',
#  'synes',
#  'faktisk',
#  'at',
#  'artiklen',
#  'er',
#  'både',
#  'nuanceret',
#  'og',
#  'velunderbygget',
#  '',
#  'Også',
#  'selvom',
#  'den',
#  'bruger',
#  'Wikipedia',
#  'som',
#  'en',
#  'kilde',
#  '',
#  'Det',
#  'kan',
#  'jeg',
#  'godt',
#  'leve',
#  'med',
#  '',
#  'når',
#  'vi',
#  'ikke',
#  'snakker',
#  'om',
#  'en',
#  'forskningsartikel',
#  'men',
#  'et',
#  'debatindlæg',
#  '',
#  'Humor',
#  '',
#  '',
#  'lige',
#  'fritid',
#  '',
#  'Hvordan',
#  'er',
#  'fordelingen',
#  'derhjemme',
#  'med',
#  'rengøring',
#  '',
#  'madlavning',
#  '',
#  'børnepasning',
#  '',
#  'tøjvalg',
#  '',
#  'indkøb',
#  'etc',
#  '',
#  'Sig',
#  'lige',
#  'ulige',
#  'fritid',
#  'en',
#  'gang',
#  'til',
#  '',
#  '',
#  '',
#  'Og',
#  'når',
#  'du',
#  'så',
#  'har',
#  'det',
#  '',
#  'så',
#  'fortæl',
#  'mig',
#  '',
#  'hvad',
#  'det',
#  'er',
#  'for',
#  'en',
#  'løgn',
#  'om',
#  'lige',
#  'løn',
#  'du',
#  'mener',
#  'der',
#  'er',
#  '',
#  'Og',
#  'når',
#  'du',
#  'har',
#  'det',
#  'så',
#  'læs',
#  'den',
#  'her',
#  '',
#  'Har',
#  'du',
#  'læst',
#  'artiklen',
#  '',
#  'Hvad',
#  'mener',
#  'du',
#  'om',
#  'indholdet',
#  'i',
#  'artiklen',
#  '',
#  'Er',
#  'du',
#  'uenig',
#  '',
#  'Og',
#  'hvis',
#  'du',
#  'er',
#  '',
#  'hvorfor',
#  '',
#  'Tag',
#  'eks',
#  'Polen',
#  'og',
#  'Ungarn',
#  '',
#  'Her',
#  'er',
#  'det',
#  'ikke',
#  'bare',
#  'muslimerne',
#  '',
#  'nu',
#  'men',
#  'også',
#  'feministerne',
#  'og',
#  'LGBT',
#  'personer',
#  'der',
#  'er',
#  'den',
#  'nye',
#  'hovedfjende',
#  '',
#  'Hvorfor',
#  'al',
#  'det',
#  'had',
#  '',
#  'Og',
#  'hvor',
#  'kommer',
#  'det',
#  'fra',
#  '',
#  'Og',
#  'se',
#  'så',
#  'tilbage',
#  'i',
#  'historien',
#  '',
#  'Hvilke',
#  'bizarre',
#  'beskyldninger',
#  '',
#  'Jeg',
#  'bøjer',
#  'mig',
#  'i',
#  'støvet',
#  '',
#  'Han',
#  'er',
#  'jo',
#  'kult',
#  '',
#  'Fisker',
#  '',
#  'Og',
#  'miljøaktivist',
#  '',
#  'Og',
#  'så',
#  'fra',
#  'Thyborøn',
#  '',
#  'Det',
#  'bliver',
#  'ikke',
#  'bedre',
#  '',
#  'Spejl',
#  '',
#  'Fuldstændig',
#  'fremragende',
#  'artikel',
#  'om',
#  'hvordan',
#  'mænds',
#  'had',
#  'til',
#  'kvinder',
#  'fører',
#  'til',
#  'overgreb',
#  '',
#  'ekstremisme',
#  'og',
#  'i',
#  'sidste',
#  'ende',
#  'terror',
#  '',
#  '',
#  'dortetoft',
#  'tak',
#  'fra',
#  'hjertet',
#  '',
#  'at',
#  'du',
#  'har',
#  'brugt',
#  'tid',
#  'på',
#  'at',
#  'skrive',
#  'en',
#  'så',
#  'reflekteret',
#  'og',
#  'underbygget',
#  'historie',
#  'om',
#  'giftig',
#  'maskulinitet',
#  '',
#  '',
#  'dkpol',
#  'Kan',
#  'kun',
#  'sige',
#  '',
#  'Enig',
#  '',
#  'Enig',
#  '',
#  'Enig',
#  '',
#  'Til',
#  'dette',
#  'Catalonien',
#  'debatindlæg',
#  'af',
#  '',
#  'EvaFlyvholm',
#  '',
#  '',
#  'pelledragsted',
#  'og',
#  '',
#  'nvillumsen',
#  'fra',
#  '',
#  'Enhedslisten',
#  '',
#  'Som',
#  'overskriften',
#  'siger',
#  '',
#  '',
#  'Politiske',
#  'konflikter',
#  'kan',
#  'og',
#  'skal',
#  'ikke',
#  'løses',
#  'med',
#  'vold',
#  'mod',
#  'vælgere',
#  'og',
#  'fængsling',
#  'af',
#  'politikere',
#  '',
#  '',
#  '',
#  'dkpol',
#  'Jeg',
#  'doserer',
#  'mine',
#  'udtalelser',
#  'i',
#  'forhold',
#  'til',
#  'problemets',
#  'omfang',
#  '',
#  'Og',
#  'jeg',
#  'er',
#  'ikke',
#  'et',
#  'sekund',
#  'i',
#  'tvivl',
#  'om',
#  '',
#  'at',
#  'den',
#  'yderste',
#  'højrefløj',
#  'i',
#  'dag',
#  'er',
#  'et',
#  'større',
#  'problem',
#  'end',
#  'den',
#  'yderste',
#  'venstrefløj',
#  '',
#  'Men',
#  'igen',
#  '',
#  'radikaliseret',
#  'fanatisme',
#  'og',
#  'dogmatisme',
#  'er',
#  'gift',
#  'for',
#  'et',
#  'stabilt',
#  'og',
#  'levende',
#  'demokrati',
#  '',
#  'Hvor',
#  'er',
#  'det',
#  'dog',
#  'en',
#  'genial',
#  'og',
#  'på',
#  'alle',
#  'måder',
#  'fremragende',
#  'og',
#  'meningsfuld',
#  'ide',
#  '',
#  'At',
#  'hylde',
#  'de',
#  'aller',
#  'bedste',
#  ...]
